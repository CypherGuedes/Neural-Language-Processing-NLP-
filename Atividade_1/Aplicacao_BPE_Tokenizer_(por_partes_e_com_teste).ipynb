# %%
#Aplicação por partes e com testes

# %%
import os
import json
import sys

# %%
# Define o caminho para a pasta 'corpus'

# %%
pasta_corpus = r'C:\Users\tagsa\Downloads\corpus'

# %%
# Função para carregar e verificar os textos dos arquivos JSON

# %%
def carregar_textos_json(pasta):
    textos = []
    arquivos_validos = 0  # Contador de arquivos JSON válidos
    textos_encontrados = 0  # Contador de textos encontrados

    if not os.path.exists(pasta):
        print(f"Pasta não encontrada: {pasta}")
        return '', []

    # Lista todos os arquivos JSON na pasta
    arquivos = [arq for arq in os.listdir(pasta) if arq.endswith('.json')]
    print(f"Número de arquivos JSON encontrados: {len(arquivos)}")

    # Verifica e extrai textos de todos os arquivos
    for arquivo in arquivos:
        caminho = os.path.join(pasta, arquivo)
        with open(caminho, "r", encoding="utf-8") as f:
            try:
                dados = json.load(f)
                arquivos_validos += 1  # Incrementa contador de arquivos lidos com sucesso

                # Verifica se o JSON é uma lista ou dicionário e extrai textos
                if isinstance(dados, list):
                    for item in dados:
                        texto = item.get('text', '')  # Alteração aqui para a chave correta
                        if texto:
                            textos.append(texto)
                            textos_encontrados += 1  # Incrementa contador de textos encontrados
                elif isinstance(dados, dict):
                    texto = dados.get('text', '')  # Alteração aqui também
                    if texto:
                        textos.append(texto)
                        textos_encontrados += 1  # Incrementa contador de textos encontrados
            except json.JSONDecodeError:
                print(f"Erro ao ler o arquivo: {arquivo}")

    corpus = ' '.join(textos)
    return corpus, textos, arquivos_validos, textos_encontrados

# %%
# Carrega o corpus e os textos e exibe a quantidade de arquivos válidos e textos encontrados

# %%
corpus, textos, arquivos_validos, textos_encontrados = carregar_textos_json(pasta_corpus)

print(f"Número de arquivos JSON válidos lidos: {arquivos_validos}")
print(f"Corpus carregado com {len(corpus)} caracteres.")
print(f"Número de textos individuais: {textos_encontrados}")
# Out:
# Número de arquivos JSON encontrados: 10000
# Número de arquivos JSON válidos lidos: 10000
# Corpus carregado com 71033256 caracteres.
# Número de textos individuais: 9996

# %%
# Adiciona o caminho do diretório onde está o bpe_tokenizer.py

# %%
sys.path.append(r'C:\Users\tagsa\Downloads')

# %%
# Importa a classe do algoritmo BPE

# %%
from bpe_tokenizer import BPE_Tokenizer

# %%
# Define o tamanho do vocabulário (276)

# %%
vocab_size = 276

# %%
# Instancia o tokenizador BPE

# %%
tokenizer = BPE_Tokenizer()

# %%
# Utiliza apenas os 1000 primeiros caracteres para teste

# %%
corpus_teste = corpus[:1000]

print("Codificando a amostra...")
encoded_teste = tokenizer.encode(corpus_teste)
print(f"Tokens codificados (amostra): {encoded_teste[:100]}...")  # Exibe os primeiros 100 tokens
# Out:
# Codificando a amostra...
# Tokens codificados (amostra): [83, 195, 163, 256, 86, 105, 99, 262, 116, 258, 258, 86, 262, 116, 111, 115, 257, 195, 169, 32, 117, 109, 257, 102, 114, 101, 103, 117, 268, 105, 257, 112, 264, 116, 117, 103, 117, 268, 257, 271, 109, 117, 110, 105, 99, 195, 173, 112, 105, 256, 261, 69, 108, 118, 97, 115, 260, 269, 263, 49, 48, 49, 44, 54, 56, 32, 107, 109, 194, 178, 32, 261, 195, 161, 114, 101, 257, 258, 55, 51, 50, 32, 104, 97, 98, 105, 116, 266, 116, 101, 259, 40, 99, 262, 115, 256, 261, 50, 48, 50]...

# %%
# Decodifica a amostra codificada

# %%
print("\nDecodificando a amostra...")
decoded_teste = tokenizer.decode(encoded_teste)
print(f"Texto decodificado (amostra): {decoded_teste[:500]}...")  # Exibe os primeiros 500 caracteres do texto decodificado
# Out:
# Decodificando a amostra...
# Texto decodificado (amostra): São Vicente e Ventosa é uma freguesia portuguesa do município de Elvas, com 101,68 km² de área e 732 habitantes (censo de 2021). A sua densidade populacional é . A freguesia que, popularmente, é conhecida por "Povo de São Vicente" é a segunda maior freguesia do país a nível de território. == História == Segundo a Monarquia Lusitana (Brandão), em Setembro de 1288 celebrou o Infante D. Afonso, irmão de D. Dinis, um contrato com a Ordem de Aviz, sobre certos bens que, ele infante, possuía em São Vi...

# %%
# Valida se a decodificação foi correta

# %%
if corpus_teste == decoded_teste:
    print("\nA decodificação foi realizada com sucesso! O texto decodificado é idêntico ao original.")
else:
    print("\nA decodificação falhou. O texto decodificado não é idêntico ao original.")
# Out:
# A decodificação foi realizada com sucesso! O texto decodificado é idêntico ao original.

# %%
# Codifica todo o corpus com o tokenizador treinado

# %%
print("Codificando o corpus...")
encoded_corpus = [tokenizer.encode(texto) for texto in textos]
print(f"Corpus codificado. Total de textos codificados: {len(encoded_corpus)}")
# Out:
# Codificando o corpus...
# Corpus codificado. Total de textos codificados: 9996

# %%
# Codifica cada texto e exibe o nome do arquivo, comprimento do texto e dos tokens

# %%
for i, (texto, nome_arquivo) in enumerate(zip(textos, os.listdir(pasta_corpus))):
    tokens = tokenizer.encode(texto)
    encoded_corpus.append(tokens)
    
    print(f"\nArquivo: {nome_arquivo}")
    print(f"Comprimento do texto original: {len(texto)} caracteres")
    print(f"Comprimento dos tokens codificados: {len(tokens)} tokens")

print(f"\nCorpus codificado. Total de textos codificados: {len(encoded_corpus)}")
# Out:
# Arquivo: 10000.json
# Comprimento do texto original: 14644 caracteres
# Comprimento dos tokens codificados: 11543 tokens
#
# Arquivo: 100008.json
# Comprimento do texto original: 1755 caracteres
# Comprimento dos tokens codificados: 1383 tokens
#
# Arquivo: 100013.json
# Comprimento do texto original: 204 caracteres
# Comprimento dos tokens codificados: 173 tokens
#
# Arquivo: 100022.json
# Comprimento do texto original: 234 caracteres
# Comprimento dos tokens codificados: 194 tokens
#
# Arquivo: 100042.json
# Comprimento do texto original: 23423 caracteres
# Comprimento dos tokens codificados: 18602 tokens
#
# Arquivo: 100093.json
# Comprimento do texto original: 1248 caracteres
# Comprimento dos tokens codificados: 1008 tokens
#
# Arquivo: 1001.json
# Comprimento do texto original: 5880 caracteres
# Comprimento dos tokens codificados: 4785 tokens
#
# Arquivo: 100105.json
# Comprimento do texto original: 12987 caracteres
# Comprimento dos tokens codificados: 10178 tokens
#
# Arquivo: 100186.json
# Comprimento do texto original: 6630 caracteres
# Comprimento dos tokens codificados: 5375 tokens
#
# Arquivo: 100187.json
# Comprimento do texto original: 556 caracteres
# Comprimento dos tokens codificados: 416 tokens
#
# Arquivo: 100207.json
# Comprimento do texto original: 4730 caracteres
# Comprimento dos tokens codificados: 3794 tokens
#
# Arquivo: 100213.json
# Comprimento do texto original: 3504 caracteres
# Comprimento dos tokens codificados: 2845 tokens
#
# Arquivo: 100232.json
# Comprimento do texto original: 354 caracteres
# Comprimento dos tokens codificados: 278 tokens
#
# Arquivo: 100235.json
# Comprimento do texto original: 1034 caracteres
# Comprimento dos tokens codificados: 812 tokens
#
# Arquivo: 100254.json
# Comprimento do texto original: 5315 caracteres
# Comprimento dos tokens codificados: 4570 tokens
#
# Arquivo: 100267.json
# Comprimento do texto original: 431 caracteres
# Comprimento dos tokens codificados: 345 tokens
#
# Arquivo: 100294.json
# Comprimento do texto original: 159 caracteres
# Comprimento dos tokens codificados: 134 tokens
#
# Arquivo: 10030.json
# Comprimento do texto original: 2424 caracteres
# Comprimento dos tokens codificados: 1941 tokens
#
# Arquivo: 100305.json
# Comprimento do texto original: 3018 caracteres
# Comprimento dos tokens codificados: 2337 tokens
#
# Arquivo: 100315.json
# Comprimento do texto original: 714 caracteres
# Comprimento dos tokens codificados: 633 tokens
#
# Arquivo: 10033.json
# Comprimento do texto original: 962 caracteres
# Comprimento dos tokens codificados: 793 tokens
#
# Arquivo: 100344.json
# Comprimento do texto original: 17827 caracteres
# Comprimento dos tokens codificados: 14476 tokens
#
# Arquivo: 100347.json
# Comprimento do texto original: 1868 caracteres
# Comprimento dos tokens codificados: 1507 tokens
#
# Arquivo: 100356.json
# Comprimento do texto original: 803 caracteres
# Comprimento dos tokens codificados: 652 tokens
#
# Arquivo: 100360.json
# Comprimento do texto original: 1566 caracteres
# Comprimento dos tokens codificados: 1327 tokens
#
# Arquivo: 100368.json
# Comprimento do texto original: 2336 caracteres
# Comprimento dos tokens codificados: 1876 tokens
#
# Arquivo: 100373.json
# Comprimento do texto original: 2138 caracteres
# Comprimento dos tokens codificados: 1767 tokens
#
# Arquivo: 100380.json
# Comprimento do texto original: 2778 caracteres
# Comprimento dos tokens codificados: 2293 tokens
#
# Arquivo: 100391.json
# Comprimento do texto original: 5739 caracteres
# Comprimento dos tokens codificados: 4629 tokens
#
# Arquivo: 10042.json
# Comprimento do texto original: 12164 caracteres
# Comprimento dos tokens codificados: 10003 tokens
#
# Arquivo: 100426.json
# Comprimento do texto original: 3183 caracteres
# Comprimento dos tokens codificados: 2506 tokens
#
# Arquivo: 100448.json
# Comprimento do texto original: 6698 caracteres
# Comprimento dos tokens codificados: 5616 tokens
#
# Arquivo: 100487.json
# Comprimento do texto original: 2868 caracteres
# Comprimento dos tokens codificados: 2383 tokens
#
# Arquivo: 100511.json
# Comprimento do texto original: 1413 caracteres
# Comprimento dos tokens codificados: 1130 tokens
#
# Arquivo: 100535.json
# Comprimento do texto original: 1946 caracteres
# Comprimento dos tokens codificados: 1534 tokens
#
# Arquivo: 10054.json
# Comprimento do texto original: 1668 caracteres
# Comprimento dos tokens codificados: 1383 tokens
#
# Arquivo: 100553.json
# Comprimento do texto original: 32363 caracteres
# Comprimento dos tokens codificados: 26069 tokens
#
# Arquivo: 100599.json
# Comprimento do texto original: 4532 caracteres
# Comprimento dos tokens codificados: 3619 tokens
#
# Arquivo: 100626.json
# Comprimento do texto original: 2854 caracteres
# Comprimento dos tokens codificados: 2399 tokens
#
# Arquivo: 10063.json
# Comprimento do texto original: 1298 caracteres
# Comprimento dos tokens codificados: 1071 tokens
#
# Arquivo: 100667.json
# Comprimento do texto original: 2354 caracteres
# Comprimento dos tokens codificados: 1932 tokens
#
# Arquivo: 100674.json
# Comprimento do texto original: 305 caracteres
# Comprimento dos tokens codificados: 241 tokens
#
# Arquivo: 100679.json
# Comprimento do texto original: 1829 caracteres
# Comprimento dos tokens codificados: 1507 tokens
#
# Arquivo: 100688.json
# Comprimento do texto original: 902 caracteres
# Comprimento dos tokens codificados: 820 tokens
#
# Arquivo: 100704.json
# Comprimento do texto original: 4028 caracteres
# Comprimento dos tokens codificados: 3248 tokens
#
# Arquivo: 100705.json
# Comprimento do texto original: 12042 caracteres
# Comprimento dos tokens codificados: 9576 tokens
#
# Arquivo: 100724.json
# Comprimento do texto original: 9124 caracteres
# Comprimento dos tokens codificados: 7266 tokens
#
# Arquivo: 10074.json
# Comprimento do texto original: 1328 caracteres
# Comprimento dos tokens codificados: 1089 tokens
#
# Arquivo: 100745.json
# Comprimento do texto original: 662 caracteres
# Comprimento dos tokens codificados: 541 tokens
#
# Arquivo: 100765.json
# Comprimento do texto original: 14777 caracteres
# Comprimento dos tokens codificados: 12137 tokens
#
# Arquivo: 100782.json
# Comprimento do texto original: 12429 caracteres
# Comprimento dos tokens codificados: 9927 tokens
#
# Arquivo: 10079.json
# Comprimento do texto original: 1345 caracteres
# Comprimento dos tokens codificados: 1072 tokens
#
# Arquivo: 100792.json
# Comprimento do texto original: 9500 caracteres
# Comprimento dos tokens codificados: 7692 tokens
#
# Arquivo: 100794.json
# Comprimento do texto original: 3270 caracteres
# Comprimento dos tokens codificados: 2643 tokens
#
# Arquivo: 100795.json
# Comprimento do texto original: 15454 caracteres
# Comprimento dos tokens codificados: 12348 tokens
#
# Arquivo: 100797.json
# Comprimento do texto original: 7912 caracteres
# Comprimento dos tokens codificados: 6256 tokens
#
# Arquivo: 10080.json
# Comprimento do texto original: 2028 caracteres
# Comprimento dos tokens codificados: 1625 tokens
#
# Arquivo: 10081.json
# Comprimento do texto original: 1542 caracteres
# Comprimento dos tokens codificados: 1244 tokens
#
# Arquivo: 100813.json
# Comprimento do texto original: 12344 caracteres
# Comprimento dos tokens codificados: 10548 tokens
#
# Arquivo: 100824.json
# Comprimento do texto original: 17149 caracteres
# Comprimento dos tokens codificados: 13725 tokens
#
# Arquivo: 10083.json
# Comprimento do texto original: 1979 caracteres
# Comprimento dos tokens codificados: 1610 tokens
#
# Arquivo: 100852.json
# Comprimento do texto original: 528 caracteres
# Comprimento dos tokens codificados: 435 tokens
#
# Arquivo: 100866.json
# Comprimento do texto original: 1406 caracteres
# Comprimento dos tokens codificados: 1098 tokens
#
# Arquivo: 100875.json
# Comprimento do texto original: 524 caracteres
# Comprimento dos tokens codificados: 434 tokens
#
# Arquivo: 100879.json
# Comprimento do texto original: 3724 caracteres
# Comprimento dos tokens codificados: 3030 tokens
#
# Arquivo: 10088.json
# Comprimento do texto original: 1721 caracteres
# Comprimento dos tokens codificados: 1410 tokens
#
# Arquivo: 100900.json
# Comprimento do texto original: 590 caracteres
# Comprimento dos tokens codificados: 482 tokens
#
# Arquivo: 100901.json
# Comprimento do texto original: 597 caracteres
# Comprimento dos tokens codificados: 501 tokens
#
# Arquivo: 100921.json
# Comprimento do texto original: 7830 caracteres
# Comprimento dos tokens codificados: 6236 tokens
#
# Arquivo: 100922.json
# Comprimento do texto original: 922 caracteres
# Comprimento dos tokens codificados: 731 tokens
#
# Arquivo: 100945.json
# Comprimento do texto original: 3358 caracteres
# Comprimento dos tokens codificados: 2660 tokens
#
# Arquivo: 100995.json
# Comprimento do texto original: 8632 caracteres
# Comprimento dos tokens codificados: 6867 tokens
#
# Arquivo: 100998.json
# Comprimento do texto original: 20912 caracteres
# Comprimento dos tokens codificados: 17310 tokens
#
# Arquivo: 10101.json
# Comprimento do texto original: 599 caracteres
# Comprimento dos tokens codificados: 481 tokens
#
# Arquivo: 101055.json
# Comprimento do texto original: 3454 caracteres
# Comprimento dos tokens codificados: 2733 tokens
#
# Arquivo: 101063.json
# Comprimento do texto original: 4580 caracteres
# Comprimento dos tokens codificados: 3692 tokens
#
# Arquivo: 101064.json
# Comprimento do texto original: 734 caracteres
# Comprimento dos tokens codificados: 593 tokens
#
# Arquivo: 101065.json
# Comprimento do texto original: 5115 caracteres
# Comprimento dos tokens codificados: 4055 tokens
#
# Arquivo: 101067.json
# Comprimento do texto original: 650 caracteres
# Comprimento dos tokens codificados: 535 tokens
#
# Arquivo: 10107.json
# Comprimento do texto original: 8970 caracteres
# Comprimento dos tokens codificados: 7348 tokens
#
# Arquivo: 101110.json
# Comprimento do texto original: 147 caracteres
# Comprimento dos tokens codificados: 130 tokens
#
# Arquivo: 101114.json
# Comprimento do texto original: 8635 caracteres
# Comprimento dos tokens codificados: 7376 tokens
#
# Arquivo: 101116.json
# Comprimento do texto original: 2968 caracteres
# Comprimento dos tokens codificados: 2417 tokens
#
# Arquivo: 101142.json
# Comprimento do texto original: 11582 caracteres
# Comprimento dos tokens codificados: 9070 tokens
#
# Arquivo: 101155.json
# Comprimento do texto original: 586 caracteres
# Comprimento dos tokens codificados: 468 tokens
#
# Arquivo: 101177.json
# Comprimento do texto original: 16414 caracteres
# Comprimento dos tokens codificados: 13257 tokens
#
# Arquivo: 101181.json
# Comprimento do texto original: 240 caracteres
# Comprimento dos tokens codificados: 197 tokens
#
# Arquivo: 101187.json
# Comprimento do texto original: 386 caracteres
# Comprimento dos tokens codificados: 311 tokens
#
# Arquivo: 101193.json
# Comprimento do texto original: 334 caracteres
# Comprimento dos tokens codificados: 268 tokens
#
# Arquivo: 101196.json
# Comprimento do texto original: 7635 caracteres
# Comprimento dos tokens codificados: 5937 tokens
#
# Arquivo: 101198.json
# Comprimento do texto original: 2972 caracteres
# Comprimento dos tokens codificados: 2348 tokens
#
# Arquivo: 10121.json
# Comprimento do texto original: 13293 caracteres
# Comprimento dos tokens codificados: 10519 tokens
#
# Arquivo: 101231.json
# Comprimento do texto original: 685 caracteres
# Comprimento dos tokens codificados: 571 tokens
#
# Arquivo: 101234.json
# Comprimento do texto original: 486 caracteres
# Comprimento dos tokens codificados: 382 tokens
#
# Arquivo: 101246.json
# Comprimento do texto original: 651 caracteres
# Comprimento dos tokens codificados: 521 tokens
#
# Arquivo: 101255.json
# Comprimento do texto original: 13525 caracteres
# Comprimento dos tokens codificados: 10493 tokens
#
# Arquivo: 101267.json
# Comprimento do texto original: 388 caracteres
# Comprimento dos tokens codificados: 309 tokens
#
# Arquivo: 101269.json
# Comprimento do texto original: 385 caracteres
# Comprimento dos tokens codificados: 313 tokens
#
# Arquivo: 10127.json
# Comprimento do texto original: 911 caracteres
# Comprimento dos tokens codificados: 719 tokens
#
# Arquivo: 101278.json
# Comprimento do texto original: 314 caracteres
# Comprimento dos tokens codificados: 259 tokens
#
# Arquivo: 10128.json
# Comprimento do texto original: 16412 caracteres
# Comprimento dos tokens codificados: 13035 tokens
#
# Arquivo: 101281.json
# Comprimento do texto original: 284 caracteres
# Comprimento dos tokens codificados: 231 tokens
#
# Arquivo: 101286.json
# Comprimento do texto original: 563 caracteres
# Comprimento dos tokens codificados: 452 tokens
#
# Arquivo: 101289.json
# Comprimento do texto original: 242 caracteres
# Comprimento dos tokens codificados: 199 tokens
#
# Arquivo: 101291.json
# Comprimento do texto original: 413 caracteres
# Comprimento dos tokens codificados: 342 tokens
#
# Arquivo: 101306.json
# Comprimento do texto original: 310 caracteres
# Comprimento dos tokens codificados: 251 tokens
#
# Arquivo: 101312.json
# Comprimento do texto original: 359 caracteres
# Comprimento dos tokens codificados: 294 tokens
#
# Arquivo: 101313.json
# Comprimento do texto original: 2051 caracteres
# Comprimento dos tokens codificados: 1670 tokens
#
# Arquivo: 101319.json
# Comprimento do texto original: 350 caracteres
# Comprimento dos tokens codificados: 283 tokens
#
# Arquivo: 101327.json
# Comprimento do texto original: 395 caracteres
# Comprimento dos tokens codificados: 332 tokens
#
# Arquivo: 101333.json
# Comprimento do texto original: 870 caracteres
# Comprimento dos tokens codificados: 695 tokens
#
# Arquivo: 101346.json
# Comprimento do texto original: 388 caracteres
# Comprimento dos tokens codificados: 311 tokens
#
# Arquivo: 101347.json
# Comprimento do texto original: 254 caracteres
# Comprimento dos tokens codificados: 206 tokens
#
# Arquivo: 101354.json
# Comprimento do texto original: 1206 caracteres
# Comprimento dos tokens codificados: 962 tokens
#
# Arquivo: 101369.json
# Comprimento do texto original: 368 caracteres
# Comprimento dos tokens codificados: 313 tokens
#
# Arquivo: 101374.json
# Comprimento do texto original: 466 caracteres
# Comprimento dos tokens codificados: 384 tokens
#
# Arquivo: 101375.json
# Comprimento do texto original: 1348 caracteres
# Comprimento dos tokens codificados: 1089 tokens
#
# Arquivo: 101378.json
# Comprimento do texto original: 351 caracteres
# Comprimento dos tokens codificados: 294 tokens
#
# Arquivo: 101393.json
# Comprimento do texto original: 415 caracteres
# Comprimento dos tokens codificados: 341 tokens
#
# Arquivo: 10140.json
# Comprimento do texto original: 1827 caracteres
# Comprimento dos tokens codificados: 1588 tokens
#
# Arquivo: 101409.json
# Comprimento do texto original: 69783 caracteres
# Comprimento dos tokens codificados: 55679 tokens
#
# Arquivo: 101410.json
# Comprimento do texto original: 942 caracteres
# Comprimento dos tokens codificados: 729 tokens
#
# Arquivo: 101411.json
# Comprimento do texto original: 15648 caracteres
# Comprimento dos tokens codificados: 12672 tokens
#
# Arquivo: 101417.json
# Comprimento do texto original: 505 caracteres
# Comprimento dos tokens codificados: 413 tokens
#
# Arquivo: 101424.json
# Comprimento do texto original: 430 caracteres
# Comprimento dos tokens codificados: 349 tokens
#
# Arquivo: 101429.json
# Comprimento do texto original: 332 caracteres
# Comprimento dos tokens codificados: 281 tokens
#
# Arquivo: 101431.json
# Comprimento do texto original: 480 caracteres
# Comprimento dos tokens codificados: 394 tokens
#
# Arquivo: 101444.json
# Comprimento do texto original: 6388 caracteres
# Comprimento dos tokens codificados: 5130 tokens
#
# Arquivo: 101449.json
# Comprimento do texto original: 10019 caracteres
# Comprimento dos tokens codificados: 8078 tokens
#
# Arquivo: 101451.json
# Comprimento do texto original: 12383 caracteres
# Comprimento dos tokens codificados: 9921 tokens
#
# Arquivo: 10146.json
# Comprimento do texto original: 29273 caracteres
# Comprimento dos tokens codificados: 23579 tokens
#
# Arquivo: 101461.json
# Comprimento do texto original: 2891 caracteres
# Comprimento dos tokens codificados: 2274 tokens
#
# Arquivo: 101467.json
# Comprimento do texto original: 7527 caracteres
# Comprimento dos tokens codificados: 6081 tokens
#
# Arquivo: 101475.json
# Comprimento do texto original: 4239 caracteres
# Comprimento dos tokens codificados: 3447 tokens
#
# Arquivo: 101513.json
# Comprimento do texto original: 3633 caracteres
# Comprimento dos tokens codificados: 2962 tokens
#
# Arquivo: 101524.json
# Comprimento do texto original: 22910 caracteres
# Comprimento dos tokens codificados: 18010 tokens
#
# Arquivo: 101535.json
# Comprimento do texto original: 699 caracteres
# Comprimento dos tokens codificados: 554 tokens
#
# Arquivo: 101537.json
# Comprimento do texto original: 4427 caracteres
# Comprimento dos tokens codificados: 3509 tokens
#
# Arquivo: 101567.json
# Comprimento do texto original: 6837 caracteres
# Comprimento dos tokens codificados: 5573 tokens
#
# Arquivo: 101585.json
# Comprimento do texto original: 1932 caracteres
# Comprimento dos tokens codificados: 1519 tokens
#
# Arquivo: 101615.json
# Comprimento do texto original: 6275 caracteres
# Comprimento dos tokens codificados: 5182 tokens
#
# Arquivo: 101622.json
# Comprimento do texto original: 2217 caracteres
# Comprimento dos tokens codificados: 1788 tokens
#
# Arquivo: 101657.json
# Comprimento do texto original: 6694 caracteres
# Comprimento dos tokens codificados: 5994 tokens
#
# Arquivo: 101662.json
# Comprimento do texto original: 19289 caracteres
# Comprimento dos tokens codificados: 16167 tokens
#
# Arquivo: 101679.json
# Comprimento do texto original: 5385 caracteres
# Comprimento dos tokens codificados: 4627 tokens
#
# Arquivo: 101687.json
# Comprimento do texto original: 7702 caracteres
# Comprimento dos tokens codificados: 6534 tokens
#
# Arquivo: 101688.json
# Comprimento do texto original: 9249 caracteres
# Comprimento dos tokens codificados: 7641 tokens
#
# Arquivo: 101689.json
# Comprimento do texto original: 8585 caracteres
# Comprimento dos tokens codificados: 6930 tokens
#
# Arquivo: 101690.json
# Comprimento do texto original: 1223 caracteres
# Comprimento dos tokens codificados: 1081 tokens
#
# Arquivo: 101703.json
# Comprimento do texto original: 18386 caracteres
# Comprimento dos tokens codificados: 15766 tokens
#
# Arquivo: 101705.json
# Comprimento do texto original: 24277 caracteres
# Comprimento dos tokens codificados: 19659 tokens
#
# Arquivo: 101710.json
# Comprimento do texto original: 19442 caracteres
# Comprimento dos tokens codificados: 16735 tokens
#
# Arquivo: 101724.json
# Comprimento do texto original: 15053 caracteres
# Comprimento dos tokens codificados: 12025 tokens
#
# Arquivo: 101726.json
# Comprimento do texto original: 14501 caracteres
# Comprimento dos tokens codificados: 11878 tokens
#
# Arquivo: 101728.json
# Comprimento do texto original: 2852 caracteres
# Comprimento dos tokens codificados: 2326 tokens
#
# Arquivo: 101730.json
# Comprimento do texto original: 3342 caracteres
# Comprimento dos tokens codificados: 2923 tokens
#
# Arquivo: 101738.json
# Comprimento do texto original: 3111 caracteres
# Comprimento dos tokens codificados: 2700 tokens
#
# Arquivo: 101740.json
# Comprimento do texto original: 1492 caracteres
# Comprimento dos tokens codificados: 1250 tokens
#
# Arquivo: 101744.json
# Comprimento do texto original: 9256 caracteres
# Comprimento dos tokens codificados: 7538 tokens
#
# Arquivo: 101753.json
# Comprimento do texto original: 5479 caracteres
# Comprimento dos tokens codificados: 4880 tokens
#
# Arquivo: 101756.json
# Comprimento do texto original: 28847 caracteres
# Comprimento dos tokens codificados: 23927 tokens
#
# Arquivo: 10176.json
# Comprimento do texto original: 19982 caracteres
# Comprimento dos tokens codificados: 18216 tokens
#
# Arquivo: 101760.json
# Comprimento do texto original: 12817 caracteres
# Comprimento dos tokens codificados: 10662 tokens
#
# Arquivo: 10177.json
# Comprimento do texto original: 142 caracteres
# Comprimento dos tokens codificados: 124 tokens
#
# Arquivo: 101771.json
# Comprimento do texto original: 2687 caracteres
# Comprimento dos tokens codificados: 2184 tokens
#
# Arquivo: 101797.json
# Comprimento do texto original: 343 caracteres
# Comprimento dos tokens codificados: 287 tokens
#
# Arquivo: 101813.json
# Comprimento do texto original: 284 caracteres
# Comprimento dos tokens codificados: 229 tokens
#
# Arquivo: 101817.json
# Comprimento do texto original: 35037 caracteres
# Comprimento dos tokens codificados: 27813 tokens
#
# Arquivo: 101818.json
# Comprimento do texto original: 2012 caracteres
# Comprimento dos tokens codificados: 1779 tokens
#
# Arquivo: 101819.json
# Comprimento do texto original: 2319 caracteres
# Comprimento dos tokens codificados: 1889 tokens
#
# Arquivo: 101828.json
# Comprimento do texto original: 57748 caracteres
# Comprimento dos tokens codificados: 45537 tokens
#
# Arquivo: 101831.json
# Comprimento do texto original: 7342 caracteres
# Comprimento dos tokens codificados: 5895 tokens
#
# Arquivo: 101925.json
# Comprimento do texto original: 2354 caracteres
# Comprimento dos tokens codificados: 1890 tokens
#
# Arquivo: 101927.json
# Comprimento do texto original: 3885 caracteres
# Comprimento dos tokens codificados: 3301 tokens
#
# Arquivo: 101933.json
# Comprimento do texto original: 3864 caracteres
# Comprimento dos tokens codificados: 3281 tokens
#
# Arquivo: 101936.json
# Comprimento do texto original: 2807 caracteres
# Comprimento dos tokens codificados: 2377 tokens
#
# Arquivo: 101997.json
# Comprimento do texto original: 40867 caracteres
# Comprimento dos tokens codificados: 32479 tokens
#
# Arquivo: 102005.json
# Comprimento do texto original: 2724 caracteres
# Comprimento dos tokens codificados: 2217 tokens
#
# Arquivo: 102011.json
# Comprimento do texto original: 6214 caracteres
# Comprimento dos tokens codificados: 5254 tokens
#
# Arquivo: 102029.json
# Comprimento do texto original: 872 caracteres
# Comprimento dos tokens codificados: 705 tokens
#
# Arquivo: 10203.json
# Comprimento do texto original: 655 caracteres
# Comprimento dos tokens codificados: 540 tokens
#
# Arquivo: 102052.json
# Comprimento do texto original: 69799 caracteres
# Comprimento dos tokens codificados: 56765 tokens
#
# Arquivo: 102068.json
# Comprimento do texto original: 15902 caracteres
# Comprimento dos tokens codificados: 12373 tokens
#
# Arquivo: 10208.json
# Comprimento do texto original: 15163 caracteres
# Comprimento dos tokens codificados: 12097 tokens
#
# Arquivo: 1021.json
# Comprimento do texto original: 2478 caracteres
# Comprimento dos tokens codificados: 2033 tokens
#
# Arquivo: 102106.json
# Comprimento do texto original: 745 caracteres
# Comprimento dos tokens codificados: 623 tokens
#
# Arquivo: 102110.json
# Comprimento do texto original: 843 caracteres
# Comprimento dos tokens codificados: 709 tokens
#
# Arquivo: 102112.json
# Comprimento do texto original: 1066 caracteres
# Comprimento dos tokens codificados: 891 tokens
#
# Arquivo: 102122.json
# Comprimento do texto original: 266 caracteres
# Comprimento dos tokens codificados: 224 tokens
#
# Arquivo: 102129.json
# Comprimento do texto original: 1194 caracteres
# Comprimento dos tokens codificados: 979 tokens
#
# Arquivo: 102134.json
# Comprimento do texto original: 926 caracteres
# Comprimento dos tokens codificados: 762 tokens
#
# Arquivo: 102135.json
# Comprimento do texto original: 1226 caracteres
# Comprimento dos tokens codificados: 1085 tokens
#
# Arquivo: 102136.json
# Comprimento do texto original: 4335 caracteres
# Comprimento dos tokens codificados: 3508 tokens
#
# Arquivo: 102154.json
# Comprimento do texto original: 500 caracteres
# Comprimento dos tokens codificados: 416 tokens
#
# Arquivo: 102159.json
# Comprimento do texto original: 353 caracteres
# Comprimento dos tokens codificados: 289 tokens
#
# Arquivo: 102160.json
# Comprimento do texto original: 383 caracteres
# Comprimento dos tokens codificados: 340 tokens
#
# Arquivo: 102175.json
# Comprimento do texto original: 3335 caracteres
# Comprimento dos tokens codificados: 2643 tokens
#
# Arquivo: 102181.json
# Comprimento do texto original: 402 caracteres
# Comprimento dos tokens codificados: 335 tokens
#
# Arquivo: 1022.json
# Comprimento do texto original: 44688 caracteres
# Comprimento dos tokens codificados: 34891 tokens
#
# Arquivo: 102206.json
# Comprimento do texto original: 678 caracteres
# Comprimento dos tokens codificados: 554 tokens
#
# Arquivo: 10222.json
# Comprimento do texto original: 41460 caracteres
# Comprimento dos tokens codificados: 33295 tokens
#
# Arquivo: 102227.json
# Comprimento do texto original: 1626 caracteres
# Comprimento dos tokens codificados: 1334 tokens
#
# Arquivo: 102247.json
# Comprimento do texto original: 6261 caracteres
# Comprimento dos tokens codificados: 5191 tokens
#
# Arquivo: 102253.json
# Comprimento do texto original: 1672 caracteres
# Comprimento dos tokens codificados: 1345 tokens
#
# Arquivo: 102274.json
# Comprimento do texto original: 7739 caracteres
# Comprimento dos tokens codificados: 6293 tokens
#
# Arquivo: 102284.json
# Comprimento do texto original: 2909 caracteres
# Comprimento dos tokens codificados: 2306 tokens
#
# Arquivo: 102286.json
# Comprimento do texto original: 1412 caracteres
# Comprimento dos tokens codificados: 1162 tokens
#
# Arquivo: 102297.json
# Comprimento do texto original: 20351 caracteres
# Comprimento dos tokens codificados: 15973 tokens
#
# Arquivo: 102302.json
# Comprimento do texto original: 959 caracteres
# Comprimento dos tokens codificados: 796 tokens
#
# Arquivo: 102306.json
# Comprimento do texto original: 1269 caracteres
# Comprimento dos tokens codificados: 1057 tokens
#
# Arquivo: 102329.json
# Comprimento do texto original: 20869 caracteres
# Comprimento dos tokens codificados: 16823 tokens
#
# Arquivo: 102336.json
# Comprimento do texto original: 19598 caracteres
# Comprimento dos tokens codificados: 15823 tokens
#
# Arquivo: 102337.json
# Comprimento do texto original: 2751 caracteres
# Comprimento dos tokens codificados: 2185 tokens
#
# Arquivo: 102346.json
# Comprimento do texto original: 34932 caracteres
# Comprimento dos tokens codificados: 28108 tokens
#
# Arquivo: 102352.json
# Comprimento do texto original: 22210 caracteres
# Comprimento dos tokens codificados: 18561 tokens
#
# Arquivo: 102354.json
# Comprimento do texto original: 269 caracteres
# Comprimento dos tokens codificados: 221 tokens
#
# Arquivo: 102361.json
# Comprimento do texto original: 4333 caracteres
# Comprimento dos tokens codificados: 3499 tokens
#
# Arquivo: 102371.json
# Comprimento do texto original: 2296 caracteres
# Comprimento dos tokens codificados: 1819 tokens
#
# Arquivo: 102380.json
# Comprimento do texto original: 259 caracteres
# Comprimento dos tokens codificados: 214 tokens
#
# Arquivo: 102387.json
# Comprimento do texto original: 257 caracteres
# Comprimento dos tokens codificados: 215 tokens
#
# Arquivo: 10241.json
# Comprimento do texto original: 861 caracteres
# Comprimento dos tokens codificados: 701 tokens
#
# Arquivo: 102410.json
# Comprimento do texto original: 262 caracteres
# Comprimento dos tokens codificados: 218 tokens
#
# Arquivo: 102415.json
# Comprimento do texto original: 270 caracteres
# Comprimento dos tokens codificados: 281 tokens
#
# Arquivo: 102417.json
# Comprimento do texto original: 264 caracteres
# Comprimento dos tokens codificados: 216 tokens
#
# Arquivo: 102425.json
# Comprimento do texto original: 257 caracteres
# Comprimento dos tokens codificados: 214 tokens
#
# Arquivo: 102433.json
# Comprimento do texto original: 261 caracteres
# Comprimento dos tokens codificados: 219 tokens
#
# Arquivo: 102444.json
# Comprimento do texto original: 1969 caracteres
# Comprimento dos tokens codificados: 1570 tokens
#
# Arquivo: 102464.json
# Comprimento do texto original: 8842 caracteres
# Comprimento dos tokens codificados: 7404 tokens
#
# Arquivo: 102482.json
# Comprimento do texto original: 373 caracteres
# Comprimento dos tokens codificados: 327 tokens
#
# Arquivo: 102490.json
# Comprimento do texto original: 14550 caracteres
# Comprimento dos tokens codificados: 11641 tokens
#
# Arquivo: 102505.json
# Comprimento do texto original: 19537 caracteres
# Comprimento dos tokens codificados: 15607 tokens
#
# Arquivo: 102526.json
# Comprimento do texto original: 270 caracteres
# Comprimento dos tokens codificados: 223 tokens
#
# Arquivo: 102528.json
# Comprimento do texto original: 273 caracteres
# Comprimento dos tokens codificados: 224 tokens
#
# Arquivo: 102531.json
# Comprimento do texto original: 272 caracteres
# Comprimento dos tokens codificados: 223 tokens
#
# Arquivo: 102532.json
# Comprimento do texto original: 270 caracteres
# Comprimento dos tokens codificados: 224 tokens
#
# Arquivo: 102537.json
# Comprimento do texto original: 898 caracteres
# Comprimento dos tokens codificados: 719 tokens
#
# Arquivo: 102551.json
# Comprimento do texto original: 274 caracteres
# Comprimento dos tokens codificados: 227 tokens
#
# Arquivo: 102553.json
# Comprimento do texto original: 278 caracteres
# Comprimento dos tokens codificados: 229 tokens
#
# Arquivo: 102560.json
# Comprimento do texto original: 269 caracteres
# Comprimento dos tokens codificados: 226 tokens
#
# Arquivo: 102561.json
# Comprimento do texto original: 643 caracteres
# Comprimento dos tokens codificados: 523 tokens
#
# Arquivo: 102563.json
# Comprimento do texto original: 516 caracteres
# Comprimento dos tokens codificados: 453 tokens
#
# Arquivo: 102568.json
# Comprimento do texto original: 545 caracteres
# Comprimento dos tokens codificados: 437 tokens
#
# Arquivo: 102575.json
# Comprimento do texto original: 261 caracteres
# Comprimento dos tokens codificados: 219 tokens
#
# Arquivo: 102580.json
# Comprimento do texto original: 258 caracteres
# Comprimento dos tokens codificados: 217 tokens
#
# Arquivo: 1026.json
# Comprimento do texto original: 49329 caracteres
# Comprimento dos tokens codificados: 39618 tokens
#
# Arquivo: 10260.json
# Comprimento do texto original: 1741 caracteres
# Comprimento dos tokens codificados: 1423 tokens
#
# Arquivo: 102606.json
# Comprimento do texto original: 425 caracteres
# Comprimento dos tokens codificados: 360 tokens
#
# Arquivo: 102624.json
# Comprimento do texto original: 255 caracteres
# Comprimento dos tokens codificados: 210 tokens
#
# Arquivo: 102629.json
# Comprimento do texto original: 264 caracteres
# Comprimento dos tokens codificados: 225 tokens
#
# Arquivo: 102633.json
# Comprimento do texto original: 288 caracteres
# Comprimento dos tokens codificados: 246 tokens
#
# Arquivo: 102637.json
# Comprimento do texto original: 505 caracteres
# Comprimento dos tokens codificados: 403 tokens
#
# Arquivo: 102652.json
# Comprimento do texto original: 271 caracteres
# Comprimento dos tokens codificados: 229 tokens
#
# Arquivo: 102662.json
# Comprimento do texto original: 259 caracteres
# Comprimento dos tokens codificados: 216 tokens
#
# Arquivo: 102666.json
# Comprimento do texto original: 545 caracteres
# Comprimento dos tokens codificados: 444 tokens
#
# Arquivo: 102676.json
# Comprimento do texto original: 261 caracteres
# Comprimento dos tokens codificados: 218 tokens
#
# Arquivo: 102683.json
# Comprimento do texto original: 1687 caracteres
# Comprimento dos tokens codificados: 1584 tokens
#
# Arquivo: 102693.json
# Comprimento do texto original: 1368 caracteres
# Comprimento dos tokens codificados: 1107 tokens
#
# Arquivo: 102695.json
# Comprimento do texto original: 6373 caracteres
# Comprimento dos tokens codificados: 5123 tokens
#
# Arquivo: 10273.json
# Comprimento do texto original: 15628 caracteres
# Comprimento dos tokens codificados: 12343 tokens
#
# Arquivo: 102731.json
# Comprimento do texto original: 604 caracteres
# Comprimento dos tokens codificados: 483 tokens
#
# Arquivo: 102735.json
# Comprimento do texto original: 10285 caracteres
# Comprimento dos tokens codificados: 7996 tokens
#
# Arquivo: 102736.json
# Comprimento do texto original: 792 caracteres
# Comprimento dos tokens codificados: 666 tokens
#
# Arquivo: 102750.json
# Comprimento do texto original: 126 caracteres
# Comprimento dos tokens codificados: 102 tokens
#
# Arquivo: 102752.json
# Comprimento do texto original: 3516 caracteres
# Comprimento dos tokens codificados: 2797 tokens
#
# Arquivo: 102756.json
# Comprimento do texto original: 477 caracteres
# Comprimento dos tokens codificados: 397 tokens
#
# Arquivo: 102772.json
# Comprimento do texto original: 2194 caracteres
# Comprimento dos tokens codificados: 1757 tokens
#
# Arquivo: 102798.json
# Comprimento do texto original: 322 caracteres
# Comprimento dos tokens codificados: 263 tokens
#
# Arquivo: 102801.json
# Comprimento do texto original: 478 caracteres
# Comprimento dos tokens codificados: 435 tokens
#
# Arquivo: 102804.json
# Comprimento do texto original: 253 caracteres
# Comprimento dos tokens codificados: 209 tokens
#
# Arquivo: 10281.json
# Comprimento do texto original: 27314 caracteres
# Comprimento dos tokens codificados: 22184 tokens
#
# Arquivo: 102840.json
# Comprimento do texto original: 66454 caracteres
# Comprimento dos tokens codificados: 52323 tokens
#
# Arquivo: 102847.json
# Comprimento do texto original: 15023 caracteres
# Comprimento dos tokens codificados: 11755 tokens
#
# Arquivo: 102855.json
# Comprimento do texto original: 681 caracteres
# Comprimento dos tokens codificados: 552 tokens
#
# Arquivo: 102869.json
# Comprimento do texto original: 423 caracteres
# Comprimento dos tokens codificados: 348 tokens
#
# Arquivo: 102872.json
# Comprimento do texto original: 443 caracteres
# Comprimento dos tokens codificados: 341 tokens
#
# Arquivo: 102878.json
# Comprimento do texto original: 308 caracteres
# Comprimento dos tokens codificados: 254 tokens
#
# Arquivo: 102898.json
# Comprimento do texto original: 357 caracteres
# Comprimento dos tokens codificados: 298 tokens
#
# Arquivo: 102905.json
# Comprimento do texto original: 335 caracteres
# Comprimento dos tokens codificados: 269 tokens
#
# Arquivo: 102906.json
# Comprimento do texto original: 274 caracteres
# Comprimento dos tokens codificados: 233 tokens
#
# Arquivo: 102911.json
# Comprimento do texto original: 20082 caracteres
# Comprimento dos tokens codificados: 16311 tokens
#
# Arquivo: 102919.json
# Comprimento do texto original: 334 caracteres
# Comprimento dos tokens codificados: 321 tokens
#
# Arquivo: 102938.json
# Comprimento do texto original: 6623 caracteres
# Comprimento dos tokens codificados: 5223 tokens
#
# Arquivo: 102959.json
# Comprimento do texto original: 44983 caracteres
# Comprimento dos tokens codificados: 36348 tokens
#
# Arquivo: 102967.json
# Comprimento do texto original: 1187 caracteres
# Comprimento dos tokens codificados: 1034 tokens
#
# Arquivo: 102979.json
# Comprimento do texto original: 490 caracteres
# Comprimento dos tokens codificados: 405 tokens
#
# Arquivo: 102980.json
# Comprimento do texto original: 388 caracteres
# Comprimento dos tokens codificados: 318 tokens
#
# Arquivo: 102988.json
# Comprimento do texto original: 1674 caracteres
# Comprimento dos tokens codificados: 1328 tokens
#
# Arquivo: 103024.json
# Comprimento do texto original: 624 caracteres
# Comprimento dos tokens codificados: 492 tokens
#
# Arquivo: 10303.json
# Comprimento do texto original: 3655 caracteres
# Comprimento dos tokens codificados: 3018 tokens
#
# Arquivo: 103036.json
# Comprimento do texto original: 3458 caracteres
# Comprimento dos tokens codificados: 2790 tokens
#
# Arquivo: 103043.json
# Comprimento do texto original: 1303 caracteres
# Comprimento dos tokens codificados: 1090 tokens
#
# Arquivo: 103045.json
# Comprimento do texto original: 886 caracteres
# Comprimento dos tokens codificados: 742 tokens
#
# Arquivo: 103047.json
# Comprimento do texto original: 4805 caracteres
# Comprimento dos tokens codificados: 3785 tokens
#
# Arquivo: 103082.json
# Comprimento do texto original: 376 caracteres
# Comprimento dos tokens codificados: 321 tokens
#
# Arquivo: 103087.json
# Comprimento do texto original: 457 caracteres
# Comprimento dos tokens codificados: 387 tokens
#
# Arquivo: 10309.json
# Comprimento do texto original: 2477 caracteres
# Comprimento dos tokens codificados: 1977 tokens
#
# Arquivo: 103096.json
# Comprimento do texto original: 24885 caracteres
# Comprimento dos tokens codificados: 19967 tokens
#
# Arquivo: 103130.json
# Comprimento do texto original: 13566 caracteres
# Comprimento dos tokens codificados: 10650 tokens
#
# Arquivo: 103140.json
# Comprimento do texto original: 29523 caracteres
# Comprimento dos tokens codificados: 27386 tokens
#
# Arquivo: 103169.json
# Comprimento do texto original: 148061 caracteres
# Comprimento dos tokens codificados: 116079 tokens
#
# Arquivo: 103175.json
# Comprimento do texto original: 11728 caracteres
# Comprimento dos tokens codificados: 9207 tokens
#
# Arquivo: 103179.json
# Comprimento do texto original: 7262 caracteres
# Comprimento dos tokens codificados: 5752 tokens
#
# Arquivo: 103181.json
# Comprimento do texto original: 6216 caracteres
# Comprimento dos tokens codificados: 4984 tokens
#
# Arquivo: 103182.json
# Comprimento do texto original: 65666 caracteres
# Comprimento dos tokens codificados: 52919 tokens
#
# Arquivo: 10319.json
# Comprimento do texto original: 14265 caracteres
# Comprimento dos tokens codificados: 11486 tokens
#
# Arquivo: 103191.json
# Comprimento do texto original: 15953 caracteres
# Comprimento dos tokens codificados: 12635 tokens
#
# Arquivo: 103209.json
# Comprimento do texto original: 4167 caracteres
# Comprimento dos tokens codificados: 3318 tokens
#
# Arquivo: 103213.json
# Comprimento do texto original: 13806 caracteres
# Comprimento dos tokens codificados: 11172 tokens
#
# Arquivo: 103220.json
# Comprimento do texto original: 6496 caracteres
# Comprimento dos tokens codificados: 5479 tokens
#
# Arquivo: 103242.json
# Comprimento do texto original: 2041 caracteres
# Comprimento dos tokens codificados: 1681 tokens
#
# Arquivo: 10327.json
# Comprimento do texto original: 4553 caracteres
# Comprimento dos tokens codificados: 3610 tokens
#
# Arquivo: 103302.json
# Comprimento do texto original: 4047 caracteres
# Comprimento dos tokens codificados: 3257 tokens
#
# Arquivo: 103309.json
# Comprimento do texto original: 4835 caracteres
# Comprimento dos tokens codificados: 3771 tokens
#
# Arquivo: 103325.json
# Comprimento do texto original: 10734 caracteres
# Comprimento dos tokens codificados: 8655 tokens
#
# Arquivo: 103339.json
# Comprimento do texto original: 3482 caracteres
# Comprimento dos tokens codificados: 2776 tokens
#
# Arquivo: 10335.json
# Comprimento do texto original: 16734 caracteres
# Comprimento dos tokens codificados: 13522 tokens
#
# Arquivo: 103381.json
# Comprimento do texto original: 3358 caracteres
# Comprimento dos tokens codificados: 2635 tokens
#
# Arquivo: 10342.json
# Comprimento do texto original: 4832 caracteres
# Comprimento dos tokens codificados: 3963 tokens
#
# Arquivo: 103438.json
# Comprimento do texto original: 31761 caracteres
# Comprimento dos tokens codificados: 26783 tokens
#
# Arquivo: 103445.json
# Comprimento do texto original: 69575 caracteres
# Comprimento dos tokens codificados: 54973 tokens
#
# Arquivo: 103492.json
# Comprimento do texto original: 942 caracteres
# Comprimento dos tokens codificados: 760 tokens
#
# Arquivo: 103493.json
# Comprimento do texto original: 3454 caracteres
# Comprimento dos tokens codificados: 2728 tokens
#
# Arquivo: 103497.json
# Comprimento do texto original: 2643 caracteres
# Comprimento dos tokens codificados: 2114 tokens
#
# Arquivo: 103502.json
# Comprimento do texto original: 978 caracteres
# Comprimento dos tokens codificados: 794 tokens
#
# Arquivo: 103511.json
# Comprimento do texto original: 6977 caracteres
# Comprimento dos tokens codificados: 5718 tokens
#
# Arquivo: 103535.json
# Comprimento do texto original: 303 caracteres
# Comprimento dos tokens codificados: 276 tokens
#
# Arquivo: 103536.json
# Comprimento do texto original: 2048 caracteres
# Comprimento dos tokens codificados: 1631 tokens
#
# Arquivo: 103546.json
# Comprimento do texto original: 3049 caracteres
# Comprimento dos tokens codificados: 2449 tokens
#
# Arquivo: 103556.json
# Comprimento do texto original: 930 caracteres
# Comprimento dos tokens codificados: 769 tokens
#
# Arquivo: 103558.json
# Comprimento do texto original: 25543 caracteres
# Comprimento dos tokens codificados: 20499 tokens
#
# Arquivo: 103567.json
# Comprimento do texto original: 365 caracteres
# Comprimento dos tokens codificados: 344 tokens
#
# Arquivo: 103570.json
# Comprimento do texto original: 1068 caracteres
# Comprimento dos tokens codificados: 995 tokens
#
# Arquivo: 103574.json
# Comprimento do texto original: 193 caracteres
# Comprimento dos tokens codificados: 177 tokens
#
# Arquivo: 103629.json
# Comprimento do texto original: 7932 caracteres
# Comprimento dos tokens codificados: 6670 tokens
#
# Arquivo: 103657.json
# Comprimento do texto original: 15828 caracteres
# Comprimento dos tokens codificados: 12674 tokens
#
# Arquivo: 103682.json
# Comprimento do texto original: 5607 caracteres
# Comprimento dos tokens codificados: 4358 tokens
#
# Arquivo: 103702.json
# Comprimento do texto original: 10132 caracteres
# Comprimento dos tokens codificados: 8256 tokens
#
# Arquivo: 103704.json
# Comprimento do texto original: 4941 caracteres
# Comprimento dos tokens codificados: 3914 tokens
#
# Arquivo: 103711.json
# Comprimento do texto original: 1567 caracteres
# Comprimento dos tokens codificados: 1217 tokens
#
# Arquivo: 103720.json
# Comprimento do texto original: 29999 caracteres
# Comprimento dos tokens codificados: 23577 tokens
#
# Arquivo: 103744.json
# Comprimento do texto original: 3277 caracteres
# Comprimento dos tokens codificados: 2764 tokens
#
# Arquivo: 103796.json
# Comprimento do texto original: 8328 caracteres
# Comprimento dos tokens codificados: 6613 tokens
#
# Arquivo: 103813.json
# Comprimento do texto original: 2477 caracteres
# Comprimento dos tokens codificados: 1967 tokens
#
# Arquivo: 103815.json
# Comprimento do texto original: 316 caracteres
# Comprimento dos tokens codificados: 276 tokens
#
# Arquivo: 103852.json
# Comprimento do texto original: 2590 caracteres
# Comprimento dos tokens codificados: 2194 tokens
#
# Arquivo: 103858.json
# Comprimento do texto original: 812 caracteres
# Comprimento dos tokens codificados: 674 tokens
#
# Arquivo: 103859.json
# Comprimento do texto original: 2914 caracteres
# Comprimento dos tokens codificados: 2298 tokens
#
# Arquivo: 103862.json
# Comprimento do texto original: 1670 caracteres
# Comprimento dos tokens codificados: 1358 tokens
#
# Arquivo: 103925.json
# Comprimento do texto original: 357 caracteres
# Comprimento dos tokens codificados: 306 tokens
#
# Arquivo: 103926.json
# Comprimento do texto original: 212 caracteres
# Comprimento dos tokens codificados: 181 tokens
#
# Arquivo: 103934.json
# Comprimento do texto original: 845 caracteres
# Comprimento dos tokens codificados: 699 tokens
#
# Arquivo: 103959.json
# Comprimento do texto original: 9421 caracteres
# Comprimento dos tokens codificados: 7616 tokens
#
# Arquivo: 103974.json
# Comprimento do texto original: 16328 caracteres
# Comprimento dos tokens codificados: 13117 tokens
#
# Arquivo: 103981.json
# Comprimento do texto original: 3256 caracteres
# Comprimento dos tokens codificados: 2675 tokens
#
# Arquivo: 104002.json
# Comprimento do texto original: 4361 caracteres
# Comprimento dos tokens codificados: 3485 tokens
#
# Arquivo: 10401.json
# Comprimento do texto original: 5275 caracteres
# Comprimento dos tokens codificados: 4162 tokens
#
# Arquivo: 104022.json
# Comprimento do texto original: 1457 caracteres
# Comprimento dos tokens codificados: 1160 tokens
#
# Arquivo: 104024.json
# Comprimento do texto original: 14885 caracteres
# Comprimento dos tokens codificados: 12097 tokens
#
# Arquivo: 104045.json
# Comprimento do texto original: 271 caracteres
# Comprimento dos tokens codificados: 226 tokens
#
# Arquivo: 104055.json
# Comprimento do texto original: 7679 caracteres
# Comprimento dos tokens codificados: 6032 tokens
#
# Arquivo: 10406.json
# Comprimento do texto original: 7418 caracteres
# Comprimento dos tokens codificados: 6129 tokens
#
# Arquivo: 104064.json
# Comprimento do texto original: 5075 caracteres
# Comprimento dos tokens codificados: 4019 tokens
#
# Arquivo: 104109.json
# Comprimento do texto original: 1330 caracteres
# Comprimento dos tokens codificados: 1044 tokens
#
# Arquivo: 104129.json
# Comprimento do texto original: 308 caracteres
# Comprimento dos tokens codificados: 261 tokens
#
# Arquivo: 104133.json
# Comprimento do texto original: 9457 caracteres
# Comprimento dos tokens codificados: 7729 tokens
#
# Arquivo: 104162.json
# Comprimento do texto original: 180 caracteres
# Comprimento dos tokens codificados: 148 tokens
#
# Arquivo: 104188.json
# Comprimento do texto original: 852 caracteres
# Comprimento dos tokens codificados: 730 tokens
#
# Arquivo: 104192.json
# Comprimento do texto original: 2319 caracteres
# Comprimento dos tokens codificados: 1850 tokens
#
# Arquivo: 104204.json
# Comprimento do texto original: 8784 caracteres
# Comprimento dos tokens codificados: 7159 tokens
#
# Arquivo: 10422.json
# Comprimento do texto original: 1133 caracteres
# Comprimento dos tokens codificados: 918 tokens
#
# Arquivo: 104223.json
# Comprimento do texto original: 282 caracteres
# Comprimento dos tokens codificados: 237 tokens
#
# Arquivo: 10423.json
# Comprimento do texto original: 11933 caracteres
# Comprimento dos tokens codificados: 9651 tokens
#
# Arquivo: 104232.json
# Comprimento do texto original: 1325 caracteres
# Comprimento dos tokens codificados: 1050 tokens
#
# Arquivo: 104260.json
# Comprimento do texto original: 2873 caracteres
# Comprimento dos tokens codificados: 2350 tokens
#
# Arquivo: 104264.json
# Comprimento do texto original: 1923 caracteres
# Comprimento dos tokens codificados: 1565 tokens
#
# Arquivo: 104265.json
# Comprimento do texto original: 307 caracteres
# Comprimento dos tokens codificados: 242 tokens
#
# Arquivo: 104283.json
# Comprimento do texto original: 655 caracteres
# Comprimento dos tokens codificados: 530 tokens
#
# Arquivo: 104305.json
# Comprimento do texto original: 351 caracteres
# Comprimento dos tokens codificados: 286 tokens
#
# Arquivo: 104308.json
# Comprimento do texto original: 7264 caracteres
# Comprimento dos tokens codificados: 5962 tokens
#
# Arquivo: 104315.json
# Comprimento do texto original: 1888 caracteres
# Comprimento dos tokens codificados: 1555 tokens
#
# Arquivo: 104316.json
# Comprimento do texto original: 2795 caracteres
# Comprimento dos tokens codificados: 2389 tokens
#
# Arquivo: 10433.json
# Comprimento do texto original: 2674 caracteres
# Comprimento dos tokens codificados: 2100 tokens
#
# Arquivo: 10436.json
# Comprimento do texto original: 2476 caracteres
# Comprimento dos tokens codificados: 1930 tokens
#
# Arquivo: 104362.json
# Comprimento do texto original: 8435 caracteres
# Comprimento dos tokens codificados: 7144 tokens
#
# Arquivo: 104367.json
# Comprimento do texto original: 1732 caracteres
# Comprimento dos tokens codificados: 1361 tokens
#
# Arquivo: 104379.json
# Comprimento do texto original: 256 caracteres
# Comprimento dos tokens codificados: 217 tokens
#
# Arquivo: 104388.json
# Comprimento do texto original: 5316 caracteres
# Comprimento dos tokens codificados: 4716 tokens
#
# Arquivo: 104397.json
# Comprimento do texto original: 753 caracteres
# Comprimento dos tokens codificados: 603 tokens
#
# Arquivo: 104411.json
# Comprimento do texto original: 3339 caracteres
# Comprimento dos tokens codificados: 2658 tokens
#
# Arquivo: 104413.json
# Comprimento do texto original: 26763 caracteres
# Comprimento dos tokens codificados: 22065 tokens
#
# Arquivo: 104457.json
# Comprimento do texto original: 8119 caracteres
# Comprimento dos tokens codificados: 6591 tokens
#
# Arquivo: 104480.json
# Comprimento do texto original: 2700 caracteres
# Comprimento dos tokens codificados: 2240 tokens
#
# Arquivo: 104487.json
# Comprimento do texto original: 8517 caracteres
# Comprimento dos tokens codificados: 6679 tokens
#
# Arquivo: 104488.json
# Comprimento do texto original: 4295 caracteres
# Comprimento dos tokens codificados: 3435 tokens
#
# Arquivo: 104518.json
# Comprimento do texto original: 1133 caracteres
# Comprimento dos tokens codificados: 912 tokens
#
# Arquivo: 104586.json
# Comprimento do texto original: 12900 caracteres
# Comprimento dos tokens codificados: 10756 tokens
#
# Arquivo: 104600.json
# Comprimento do texto original: 5991 caracteres
# Comprimento dos tokens codificados: 5309 tokens
#
# Arquivo: 104603.json
# Comprimento do texto original: 4419 caracteres
# Comprimento dos tokens codificados: 3917 tokens
#
# Arquivo: 104604.json
# Comprimento do texto original: 517 caracteres
# Comprimento dos tokens codificados: 431 tokens
#
# Arquivo: 104608.json
# Comprimento do texto original: 7109 caracteres
# Comprimento dos tokens codificados: 6348 tokens
#
# Arquivo: 10461.json
# Comprimento do texto original: 538 caracteres
# Comprimento dos tokens codificados: 453 tokens
#
# Arquivo: 104622.json
# Comprimento do texto original: 5288 caracteres
# Comprimento dos tokens codificados: 4404 tokens
#
# Arquivo: 104624.json
# Comprimento do texto original: 5177 caracteres
# Comprimento dos tokens codificados: 4668 tokens
#
# Arquivo: 104635.json
# Comprimento do texto original: 1911 caracteres
# Comprimento dos tokens codificados: 1598 tokens
#
# Arquivo: 104644.json
# Comprimento do texto original: 1870 caracteres
# Comprimento dos tokens codificados: 1465 tokens
#
# Arquivo: 104673.json
# Comprimento do texto original: 760 caracteres
# Comprimento dos tokens codificados: 622 tokens
#
# Arquivo: 104732.json
# Comprimento do texto original: 6544 caracteres
# Comprimento dos tokens codificados: 5325 tokens
#
# Arquivo: 104745.json
# Comprimento do texto original: 2294 caracteres
# Comprimento dos tokens codificados: 1938 tokens
#
# Arquivo: 104750.json
# Comprimento do texto original: 116 caracteres
# Comprimento dos tokens codificados: 99 tokens
#
# Arquivo: 104751.json
# Comprimento do texto original: 834 caracteres
# Comprimento dos tokens codificados: 683 tokens
#
# Arquivo: 10477.json
# Comprimento do texto original: 286 caracteres
# Comprimento dos tokens codificados: 245 tokens
#
# Arquivo: 104800.json
# Comprimento do texto original: 3617 caracteres
# Comprimento dos tokens codificados: 2937 tokens
#
# ...
# Comprimento do texto original: 25188 caracteres
# Comprimento dos tokens codificados: 19948 tokens
#
# Arquivo: 9761.json
# Comprimento do texto original: 1426 caracteres
# Comprimento dos tokens codificados: 1190 tokens
#
# Arquivo: 97614.json
# Comprimento do texto original: 1709 caracteres
# Comprimento dos tokens codificados: 1370 tokens
#
# Arquivo: 97656.json
# Comprimento do texto original: 440 caracteres
# Comprimento dos tokens codificados: 371 tokens
#
# Arquivo: 97670.json
# Comprimento do texto original: 2595 caracteres
# Comprimento dos tokens codificados: 2059 tokens
#
# Arquivo: 97696.json
# Comprimento do texto original: 5598 caracteres
# Comprimento dos tokens codificados: 4413 tokens
#
# Arquivo: 97705.json
# Comprimento do texto original: 539 caracteres
# Comprimento dos tokens codificados: 431 tokens
#
# Arquivo: 97715.json
# Comprimento do texto original: 692 caracteres
# Comprimento dos tokens codificados: 589 tokens
#
# Arquivo: 9774.json
# Comprimento do texto original: 600 caracteres
# Comprimento dos tokens codificados: 488 tokens
#
# Arquivo: 97766.json
# Comprimento do texto original: 68 caracteres
# Comprimento dos tokens codificados: 65 tokens
#
# Arquivo: 97786.json
# Comprimento do texto original: 21763 caracteres
# Comprimento dos tokens codificados: 17768 tokens
#
# Arquivo: 97790.json
# Comprimento do texto original: 6280 caracteres
# Comprimento dos tokens codificados: 5113 tokens
#
# Arquivo: 97799.json
# Comprimento do texto original: 9138 caracteres
# Comprimento dos tokens codificados: 7228 tokens
#
# Arquivo: 97806.json
# Comprimento do texto original: 979 caracteres
# Comprimento dos tokens codificados: 803 tokens
#
# Arquivo: 97813.json
# Comprimento do texto original: 26895 caracteres
# Comprimento dos tokens codificados: 20485 tokens
#
# Arquivo: 97831.json
# Comprimento do texto original: 10802 caracteres
# Comprimento dos tokens codificados: 8967 tokens
#
# Arquivo: 97835.json
# Comprimento do texto original: 15822 caracteres
# Comprimento dos tokens codificados: 12650 tokens
#
# Arquivo: 97848.json
# Comprimento do texto original: 1400 caracteres
# Comprimento dos tokens codificados: 1102 tokens
#
# Arquivo: 97849.json
# Comprimento do texto original: 23463 caracteres
# Comprimento dos tokens codificados: 18809 tokens
#
# Arquivo: 97857.json
# Comprimento do texto original: 2227 caracteres
# Comprimento dos tokens codificados: 1753 tokens
#
# Arquivo: 97858.json
# Comprimento do texto original: 19590 caracteres
# Comprimento dos tokens codificados: 15502 tokens
#
# Arquivo: 97864.json
# Comprimento do texto original: 18016 caracteres
# Comprimento dos tokens codificados: 15340 tokens
#
# Arquivo: 979.json
# Comprimento do texto original: 18933 caracteres
# Comprimento dos tokens codificados: 16267 tokens
#
# Arquivo: 97910.json
# Comprimento do texto original: 3875 caracteres
# Comprimento dos tokens codificados: 3140 tokens
#
# Arquivo: 9793.json
# Comprimento do texto original: 12214 caracteres
# Comprimento dos tokens codificados: 9803 tokens
#
# Arquivo: 9796.json
# Comprimento do texto original: 4289 caracteres
# Comprimento dos tokens codificados: 3433 tokens
#
# Arquivo: 9797.json
# Comprimento do texto original: 10702 caracteres
# Comprimento dos tokens codificados: 8458 tokens
#
# Arquivo: 97992.json
# Comprimento do texto original: 3759 caracteres
# Comprimento dos tokens codificados: 2998 tokens
#
# Arquivo: 98076.json
# Comprimento do texto original: 5388 caracteres
# Comprimento dos tokens codificados: 4236 tokens
#
# Arquivo: 98079.json
# Comprimento do texto original: 3321 caracteres
# Comprimento dos tokens codificados: 2646 tokens
#
# Arquivo: 98102.json
# Comprimento do texto original: 162 caracteres
# Comprimento dos tokens codificados: 126 tokens
#
# Arquivo: 98105.json
# Comprimento do texto original: 8444 caracteres
# Comprimento dos tokens codificados: 6609 tokens
#
# Arquivo: 9812.json
# Comprimento do texto original: 3682 caracteres
# Comprimento dos tokens codificados: 2983 tokens
#
# Arquivo: 98126.json
# Comprimento do texto original: 1137 caracteres
# Comprimento dos tokens codificados: 883 tokens
#
# Arquivo: 98130.json
# Comprimento do texto original: 245 caracteres
# Comprimento dos tokens codificados: 199 tokens
#
# Arquivo: 98131.json
# Comprimento do texto original: 22266 caracteres
# Comprimento dos tokens codificados: 18005 tokens
#
# Arquivo: 98133.json
# Comprimento do texto original: 252 caracteres
# Comprimento dos tokens codificados: 221 tokens
#
# Arquivo: 98141.json
# Comprimento do texto original: 9855 caracteres
# Comprimento dos tokens codificados: 7771 tokens
#
# Arquivo: 98152.json
# Comprimento do texto original: 1874 caracteres
# Comprimento dos tokens codificados: 1513 tokens
#
# Arquivo: 98167.json
# Comprimento do texto original: 809 caracteres
# Comprimento dos tokens codificados: 657 tokens
#
# Arquivo: 98169.json
# Comprimento do texto original: 5974 caracteres
# Comprimento dos tokens codificados: 4847 tokens
#
# Arquivo: 98184.json
# Comprimento do texto original: 3980 caracteres
# Comprimento dos tokens codificados: 3179 tokens
#
# Arquivo: 9821.json
# Comprimento do texto original: 12100 caracteres
# Comprimento dos tokens codificados: 9636 tokens
#
# Arquivo: 98211.json
# Comprimento do texto original: 2954 caracteres
# Comprimento dos tokens codificados: 2454 tokens
#
# Arquivo: 98241.json
# Comprimento do texto original: 16040 caracteres
# Comprimento dos tokens codificados: 13104 tokens
#
# Arquivo: 98257.json
# Comprimento do texto original: 403 caracteres
# Comprimento dos tokens codificados: 338 tokens
#
# Arquivo: 98259.json
# Comprimento do texto original: 11725 caracteres
# Comprimento dos tokens codificados: 9725 tokens
#
# Arquivo: 98270.json
# Comprimento do texto original: 610 caracteres
# Comprimento dos tokens codificados: 493 tokens
#
# Arquivo: 9828.json
# Comprimento do texto original: 2215 caracteres
# Comprimento dos tokens codificados: 1858 tokens
#
# Arquivo: 98296.json
# Comprimento do texto original: 362 caracteres
# Comprimento dos tokens codificados: 314 tokens
#
# Arquivo: 98308.json
# Comprimento do texto original: 2031 caracteres
# Comprimento dos tokens codificados: 1752 tokens
#
# Arquivo: 9831.json
# Comprimento do texto original: 494 caracteres
# Comprimento dos tokens codificados: 408 tokens
#
# Arquivo: 9839.json
# Comprimento do texto original: 10111 caracteres
# Comprimento dos tokens codificados: 8255 tokens
#
# Arquivo: 98463.json
# Comprimento do texto original: 1346 caracteres
# Comprimento dos tokens codificados: 1142 tokens
#
# Arquivo: 98516.json
# Comprimento do texto original: 3788 caracteres
# Comprimento dos tokens codificados: 3234 tokens
#
# Arquivo: 98518.json
# Comprimento do texto original: 263 caracteres
# Comprimento dos tokens codificados: 211 tokens
#
# Arquivo: 98534.json
# Comprimento do texto original: 1801 caracteres
# Comprimento dos tokens codificados: 1488 tokens
#
# Arquivo: 98545.json
# Comprimento do texto original: 2286 caracteres
# Comprimento dos tokens codificados: 1779 tokens
#
# Arquivo: 98548.json
# Comprimento do texto original: 27393 caracteres
# Comprimento dos tokens codificados: 22011 tokens
#
# Arquivo: 98569.json
# Comprimento do texto original: 4290 caracteres
# Comprimento dos tokens codificados: 3588 tokens
#
# Arquivo: 98583.json
# Comprimento do texto original: 2251 caracteres
# Comprimento dos tokens codificados: 1769 tokens
#
# Arquivo: 98585.json
# Comprimento do texto original: 820 caracteres
# Comprimento dos tokens codificados: 713 tokens
#
# Arquivo: 9859.json
# Comprimento do texto original: 14318 caracteres
# Comprimento dos tokens codificados: 11227 tokens
#
# Arquivo: 98601.json
# Comprimento do texto original: 1136 caracteres
# Comprimento dos tokens codificados: 974 tokens
#
# Arquivo: 98606.json
# Comprimento do texto original: 33473 caracteres
# Comprimento dos tokens codificados: 26694 tokens
#
# Arquivo: 98613.json
# Comprimento do texto original: 3917 caracteres
# Comprimento dos tokens codificados: 3104 tokens
#
# Arquivo: 98635.json
# Comprimento do texto original: 825 caracteres
# Comprimento dos tokens codificados: 660 tokens
#
# Arquivo: 98691.json
# Comprimento do texto original: 2141 caracteres
# Comprimento dos tokens codificados: 1717 tokens
#
# Arquivo: 987.json
# Comprimento do texto original: 733 caracteres
# Comprimento dos tokens codificados: 595 tokens
#
# Arquivo: 98720.json
# Comprimento do texto original: 12495 caracteres
# Comprimento dos tokens codificados: 9816 tokens
#
# Arquivo: 98750.json
# Comprimento do texto original: 4989 caracteres
# Comprimento dos tokens codificados: 4125 tokens
#
# Arquivo: 98782.json
# Comprimento do texto original: 456 caracteres
# Comprimento dos tokens codificados: 356 tokens
#
# Arquivo: 98790.json
# Comprimento do texto original: 197 caracteres
# Comprimento dos tokens codificados: 168 tokens
#
# Arquivo: 9881.json
# Comprimento do texto original: 3186 caracteres
# Comprimento dos tokens codificados: 2627 tokens
#
# Arquivo: 98814.json
# Comprimento do texto original: 10074 caracteres
# Comprimento dos tokens codificados: 8200 tokens
#
# Arquivo: 98854.json
# Comprimento do texto original: 8732 caracteres
# Comprimento dos tokens codificados: 7436 tokens
#
# Arquivo: 98867.json
# Comprimento do texto original: 3790 caracteres
# Comprimento dos tokens codificados: 3019 tokens
#
# Arquivo: 98869.json
# Comprimento do texto original: 2275 caracteres
# Comprimento dos tokens codificados: 1807 tokens
#
# Arquivo: 98881.json
# Comprimento do texto original: 1169 caracteres
# Comprimento dos tokens codificados: 944 tokens
#
# Arquivo: 98917.json
# Comprimento do texto original: 1075 caracteres
# Comprimento dos tokens codificados: 879 tokens
#
# Arquivo: 98922.json
# Comprimento do texto original: 1529 caracteres
# Comprimento dos tokens codificados: 1286 tokens
#
# Arquivo: 98931.json
# Comprimento do texto original: 68638 caracteres
# Comprimento dos tokens codificados: 54906 tokens
#
# Arquivo: 98933.json
# Comprimento do texto original: 3808 caracteres
# Comprimento dos tokens codificados: 3134 tokens
#
# Arquivo: 98998.json
# Comprimento do texto original: 54868 caracteres
# Comprimento dos tokens codificados: 43828 tokens
#
# Arquivo: 99015.json
# Comprimento do texto original: 48998 caracteres
# Comprimento dos tokens codificados: 41130 tokens
#
# Arquivo: 9902.json
# Comprimento do texto original: 4383 caracteres
# Comprimento dos tokens codificados: 3549 tokens
#
# Arquivo: 99087.json
# Comprimento do texto original: 9759 caracteres
# Comprimento dos tokens codificados: 7676 tokens
#
# Arquivo: 991.json
# Comprimento do texto original: 2325 caracteres
# Comprimento dos tokens codificados: 1912 tokens
#
# Arquivo: 9910.json
# Comprimento do texto original: 237 caracteres
# Comprimento dos tokens codificados: 216 tokens
#
# Arquivo: 99151.json
# Comprimento do texto original: 5781 caracteres
# Comprimento dos tokens codificados: 4780 tokens
#
# Arquivo: 9917.json
# Comprimento do texto original: 7435 caracteres
# Comprimento dos tokens codificados: 6363 tokens
#
# Arquivo: 99213.json
# Comprimento do texto original: 9805 caracteres
# Comprimento dos tokens codificados: 8282 tokens
#
# Arquivo: 9922.json
# Comprimento do texto original: 2060 caracteres
# Comprimento dos tokens codificados: 1750 tokens
#
# Arquivo: 9925.json
# Comprimento do texto original: 805 caracteres
# Comprimento dos tokens codificados: 682 tokens
#
# Arquivo: 99264.json
# Comprimento do texto original: 182 caracteres
# Comprimento dos tokens codificados: 151 tokens
#
# Arquivo: 99265.json
# Comprimento do texto original: 8155 caracteres
# Comprimento dos tokens codificados: 6339 tokens
#
# Arquivo: 99294.json
# Comprimento do texto original: 27902 caracteres
# Comprimento dos tokens codificados: 22732 tokens
#
# Arquivo: 99299.json
# Comprimento do texto original: 3340 caracteres
# Comprimento dos tokens codificados: 2711 tokens
#
# Arquivo: 99309.json
# Comprimento do texto original: 1483 caracteres
# Comprimento dos tokens codificados: 1192 tokens
#
# Arquivo: 99314.json
# Comprimento do texto original: 2584 caracteres
# Comprimento dos tokens codificados: 2131 tokens
#
# Arquivo: 99321.json
# Comprimento do texto original: 1793 caracteres
# Comprimento dos tokens codificados: 1377 tokens
#
# Arquivo: 9935.json
# Comprimento do texto original: 441 caracteres
# Comprimento dos tokens codificados: 352 tokens
#
# Arquivo: 99353.json
# Comprimento do texto original: 4538 caracteres
# Comprimento dos tokens codificados: 4067 tokens
#
# Arquivo: 99370.json
# Comprimento do texto original: 909 caracteres
# Comprimento dos tokens codificados: 735 tokens
#
# Arquivo: 99493.json
# Comprimento do texto original: 8729 caracteres
# Comprimento dos tokens codificados: 7036 tokens
#
# Arquivo: 99512.json
# Comprimento do texto original: 6511 caracteres
# Comprimento dos tokens codificados: 5160 tokens
#
# Arquivo: 99520.json
# Comprimento do texto original: 9797 caracteres
# Comprimento dos tokens codificados: 7866 tokens
#
# Arquivo: 99521.json
# Comprimento do texto original: 798 caracteres
# Comprimento dos tokens codificados: 647 tokens
#
# Arquivo: 99526.json
# Comprimento do texto original: 612 caracteres
# Comprimento dos tokens codificados: 488 tokens
#
# Arquivo: 99553.json
# Comprimento do texto original: 6921 caracteres
# Comprimento dos tokens codificados: 5555 tokens
#
# Arquivo: 99575.json
# Comprimento do texto original: 173 caracteres
# Comprimento dos tokens codificados: 152 tokens
#
# Arquivo: 99583.json
# Comprimento do texto original: 1362 caracteres
# Comprimento dos tokens codificados: 1058 tokens
#
# Arquivo: 99588.json
# Comprimento do texto original: 1119 caracteres
# Comprimento dos tokens codificados: 913 tokens
#
# Arquivo: 99593.json
# Comprimento do texto original: 2746 caracteres
# Comprimento dos tokens codificados: 2159 tokens
#
# Arquivo: 99595.json
# Comprimento do texto original: 18927 caracteres
# Comprimento dos tokens codificados: 15366 tokens
#
# Arquivo: 99622.json
# Comprimento do texto original: 10077 caracteres
# Comprimento dos tokens codificados: 8128 tokens
#
# Arquivo: 99626.json
# Comprimento do texto original: 4206 caracteres
# Comprimento dos tokens codificados: 3339 tokens
#
# Arquivo: 99633.json
# Comprimento do texto original: 1141 caracteres
# Comprimento dos tokens codificados: 930 tokens
#
# Arquivo: 99639.json
# Comprimento do texto original: 7122 caracteres
# Comprimento dos tokens codificados: 5766 tokens
#
# Arquivo: 9964.json
# Comprimento do texto original: 1852 caracteres
# Comprimento dos tokens codificados: 1491 tokens
#
# Arquivo: 99652.json
# Comprimento do texto original: 5660 caracteres
# Comprimento dos tokens codificados: 4536 tokens
#
# Arquivo: 99669.json
# Comprimento do texto original: 751 caracteres
# Comprimento dos tokens codificados: 595 tokens
#
# Arquivo: 9972.json
# Comprimento do texto original: 12634 caracteres
# Comprimento dos tokens codificados: 10111 tokens
#
# Arquivo: 99746.json
# Comprimento do texto original: 246 caracteres
# Comprimento dos tokens codificados: 206 tokens
#
# Arquivo: 99777.json
# Comprimento do texto original: 1282 caracteres
# Comprimento dos tokens codificados: 1081 tokens
#
# Arquivo: 99795.json
# Comprimento do texto original: 3185 caracteres
# Comprimento dos tokens codificados: 2559 tokens
#
# Arquivo: 99800.json
# Comprimento do texto original: 1698 caracteres
# Comprimento dos tokens codificados: 1409 tokens
#
# Arquivo: 99817.json
# Comprimento do texto original: 5431 caracteres
# Comprimento dos tokens codificados: 4772 tokens
#
# Arquivo: 9982.json
# Comprimento do texto original: 292 caracteres
# Comprimento dos tokens codificados: 261 tokens
#
# Arquivo: 99823.json
# Comprimento do texto original: 444 caracteres
# Comprimento dos tokens codificados: 364 tokens
#
# Arquivo: 99838.json
# Comprimento do texto original: 8943 caracteres
# Comprimento dos tokens codificados: 7011 tokens
#
# Arquivo: 9985.json
# Comprimento do texto original: 897 caracteres
# Comprimento dos tokens codificados: 752 tokens
#
# Arquivo: 99863.json
# Comprimento do texto original: 2537 caracteres
# Comprimento dos tokens codificados: 2046 tokens
#
# Arquivo: 99871.json
# Comprimento do texto original: 3071 caracteres
# Comprimento dos tokens codificados: 2437 tokens
#
# Arquivo: 99901.json
# Comprimento do texto original: 645 caracteres
# Comprimento dos tokens codificados: 538 tokens
#
# Arquivo: 99928.json
# Comprimento do texto original: 2056 caracteres
# Comprimento dos tokens codificados: 1699 tokens
#
# Arquivo: 9993.json
# Comprimento do texto original: 3597 caracteres
# Comprimento dos tokens codificados: 2831 tokens
#
# Arquivo: 99933.json
# Comprimento do texto original: 8556 caracteres
# Comprimento dos tokens codificados: 6759 tokens
#
# Corpus codificado. Total de textos codificados: 19992

# %%
# Acessa o método get_stats utilizando o objeto instanciado do tokenizador

# %%
stats = tokenizer.get_stats(tokens)

# %%
# Encontra o par mais frequente

# %%
top_pair = max(stats, key=stats.get)
print(f"Par mais frequente: {top_pair}")
# Out:
# Par mais frequente: (195, 167)

# %%
# Usa o objeto instanciado para chamar o método merge

# %%
tokens2 = tokenizer.merge(tokens, top_pair, 256)

# %%
# Imprime o resultado e o comprimento dos tokens após o merge

# %%
print(tokens2)
print(f"Comprimento após o merge: {len(tokens2)} tokens")
# Out:
# [69, 263, 69, 269, 110, 111, 109, 105, 97, 260, 195, 169, 32, 117, 263, 273, 115, 116, 114, 117, 109, 262, 116, 256, 100, 257, 269, 110, 116, 97, 98, 105, 108, 105, 100, 97, 261, 110, 97, 99, 105, 111, 110, 274, 32, 114, 101, 102, 265, 262, 116, 258, 195, 160, 32, 100, 268, 99, 114, 105, 256, 195, 163, 256, 100, 275, 114, 101, 108, 97, 256, 195, 181, 101, 259, 269, 109, 265, 99, 105, 97, 105, 259, 261, 117, 263, 112, 97, 195, 173, 259, 269, 263, 256, 114, 268, 116, 256, 271, 109, 117, 110, 100, 111, 270, 82, 101, 103, 105, 115, 116, 114, 257, 256, 116, 111, 116, 274, 32, 261, 100, 273, 104, 101, 105, 114, 256, 113, 117, 258, 262, 116, 114, 257, 258, 115, 97, 105, 32, 261, 117, 263, 112, 97, 195, 173, 115, 260, 110, 257, 102, 264, 109, 257, 261, 105, 109, 112, 264, 116, 97, 256, 195, 181, 101, 259, 258, 101, 120, 112, 264, 116, 97, 256, 195, 181, 101, 259, 261, 112, 114, 111, 100, 117, 116, 111, 115, 260, 115, 265, 118, 105, 256, 111, 115, 260, 99, 97, 112, 105, 116, 274, 32, 102, 273, 266, 99, 101, 105, 114, 111, 260, 98, 101, 263, 269, 109, 256, 116, 114, 266, 115, 102, 265, 195, 170, 110, 99, 105, 275, 269, 109, 265, 99, 105, 97, 105, 115, 270, 69, 120, 105, 115, 116, 101, 263, 100, 117, 275, 269, 110, 116, 275, 113, 117, 258, 114, 268, 117, 109, 101, 263, 275, 116, 114, 266, 115, 97, 256, 195, 181, 101, 259, 101, 269, 110, 195, 180, 109, 105, 99, 275, 261, 117, 263, 112, 97, 195, 173, 115, 58, 32, 42, 32, 257, 269, 110, 116, 257, 99, 264, 114, 262, 116, 101, 260, 113, 117, 258, 114, 101, 103, 105, 115, 116, 114, 257, 275, 262, 116, 114, 97, 100, 275, 258, 115, 97, 195, 173, 100, 275, 100, 101, 118, 105, 100, 275, 97, 256, 269, 109, 195, 169, 114, 99, 105, 256, 261, 98, 262, 259, 258, 115, 265, 118, 105, 256, 111, 115, 260, 98, 101, 263, 269, 109, 256, 112, 97, 103, 97, 109, 262, 116, 272, 261, 116, 114, 266, 115, 102, 265, 195, 170, 110, 99, 105, 97, 115, 59, 32, 258, 42, 32, 257, 269, 110, 116, 257, 99, 97, 112, 105, 116, 274, 32, 258, 102, 273, 266, 99, 101, 105, 114, 97, 44, 78, 256, 66, 114, 97, 115, 105, 108, 260, 97, 116, 195, 169, 32, 50, 48, 48, 49, 260, 257, 67, 111, 110, 116, 257, 67, 97, 112, 105, 116, 274, 32, 258, 70, 273, 266, 99, 101, 105, 114, 257, 265, 257, 99, 104, 97, 109, 97, 100, 257, 97, 112, 262, 275, 261, 34, 269, 110, 116, 257, 261, 99, 97, 112, 105, 116, 274, 34, 32, 111, 117, 32, 34, 109, 111, 118, 105, 109, 262, 116, 256, 261, 99, 97, 112, 105, 116, 97, 105, 115, 226, 128, 157, 270, 69, 115, 115, 101, 259, 116, 265, 109, 272, 97, 273, 100, 257, 97, 112, 267, 101, 99, 101, 263, 269, 263, 102, 114, 101, 113, 195, 188, 195, 170, 110, 99, 105, 257, 110, 257, 108, 105, 116, 265, 97, 116, 117, 114, 257, 101, 269, 110, 195, 180, 109, 105, 99, 97, 260, 112, 267, 257, 100, 268, 105, 103, 110, 267, 32, 256, 115, 101, 103, 117, 110, 271, 103, 114, 117, 112, 256, 261, 269, 110, 116, 275, 100, 257, 98, 274, 266, 256, 257, 261, 112, 97, 103, 97, 109, 262, 116, 272, 40, 113, 117, 258, 101, 263, 273, 103, 108, 195, 170, 259, 195, 169, 32, 99, 104, 97, 109, 97, 100, 111, 260, 266, 274, 111, 103, 97, 109, 262, 116, 101, 260, 261, 99, 97, 112, 105, 116, 274, 32, 97, 99, 269, 117, 110, 116, 41, 270, 69, 110, 116, 114, 101, 116, 266, 116, 111, 260, 110, 257, 110, 111, 109, 262, 99, 108, 97, 116, 117, 114, 257, 97, 116, 117, 274, 109, 262, 116, 258, 97, 100, 111, 116, 97, 100, 257, 112, 101, 108, 256, 66, 266, 99, 256, 67, 262, 116, 114, 274, 32, 271, 66, 114, 97, 115, 105, 108, 260, 257, 34, 269, 110, 116, 257, 99, 97, 112, 105, 116, 274, 34, 32, 115, 258, 114, 101, 102, 265, 258, 97, 112, 262, 275, 257, 116, 114, 266, 115, 102, 265, 195, 170, 110, 99, 105, 275, 117, 110, 105, 108, 97, 116, 265, 97, 105, 259, 261, 112, 97, 116, 114, 105, 109, 195, 180, 110, 105, 256, 261, 109, 105, 103, 114, 266, 116, 101, 259, 258, 257, 97, 113, 117, 105, 115, 105, 256, 195, 163, 256, 111, 117, 32, 274, 105, 262, 97, 256, 195, 163, 256, 261, 98, 262, 259, 110, 195, 163, 256, 112, 114, 111, 100, 117, 122, 105, 100, 272, 110, 195, 163 ...
# Comprimento após o merge: 6661 tokens

# %%
# Define do tamanho do vocabulário e número de merges

# %%
vocab_size = 276
num_merges = vocab_size - 256
ids = list(tokens)  # Lista inicial de tokens

# %%
# Dicionário para armazenar os merges realizados

# %%
merges = {}

# %%
# Realiza os merges e exibe a frequência de cada novo token criado

# %%
for i in range(num_merges):
    # Obtém as estatísticas dos pares mais frequentes
    stats = tokenizer.get_stats(ids)
    pair = max(stats, key=stats.get)  # Par mais frequente
    freq = stats[pair]  # Frequência do par
    idx = 256 + i  # Índice do novo token

    # Exibe o par sendo mesclado, o novo token e sua frequência
    print(f"Mesclando {pair} em um novo token {idx} com frequência {freq}")

    # Realiza o merge e armazena no dicionário de merges
    ids = tokenizer.merge(ids, pair, idx)
    merges[pair] = (idx, freq)  # Armazena o índice e a frequência

# %%
# Imprime o comprimento dos tokens e dos IDs após o processo de tokenização e merges

# %%
print("Comprimento do token", len(tokens))
print("Comprimento do ds", len(ids))
# Out:
# Comprimento do token 6759
# Comprimento do ds 5795

# %%
# Mostra a eficiência do processo de tokenização em termos de compressão

# %%
print(f"Taxa de compressão: {len(tokens) / len(ids):.2f}X")
# Out:
# Taxa de compressão: 1.17X

# %%
# A compressão foi de 1.17X, o que significa que o processo conseguiu reduzir o número de tokens em aproximadamente 17%
